# %% [markdown]
# lets import all the required packages

# %%
pip install --upgrade pip setuptools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 15.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 30.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.2.2
#     Uninstalling setuptools-68.2.2:
#       Successfully uninstalled setuptools-68.2.2
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip cache purge
# Out:
# Files removed: 211
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install tensorflow stable-baselines3 gym-anytrading gym
# Out:
# ...
#   Using cached tensorflow-2.15.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.6 kB)
# ...
#   Using cached gym_anytrading-2.0.0-py3-none-any.whl.metadata (292 bytes)
# ...
#   Using cached gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached tensorflow_macos-2.15.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.2 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# ...
#   Using cached gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached h5py-3.10.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.5 kB)
# ...
#   Using cached libclang-16.0.6-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# ...

# %% [markdown]
# ---------------------
# import important stuff
# ---------------------

# %%
import gym
import gym_anytrading

#DummyVecEnv is used to wrap a single environment (such as a Gym environment) into a vectorized environment, allowing for batched inference or training.
from stable_baselines3.common.vec_env import DummyVecEnv
# A2C combines the advantages of both policy-based methods (such as REINFORCE) and value-based methods (such as Q-learning) into a single framework.
from stable_baselines3 import A2C

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ---------------------
# step 1 the dataset

# %%
df = pd.read_csv('filename.csv') # read csv
